# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisPalominoR/Clase-3/blob/main/3b_PROTO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# **Data frames**

# %% [markdown]
# Creación

# %%
SurnamesP=["Milei", "Arce", "da Silva", "Boric", "Petro", "Chaves", "Díaz-Canel",
           "Noboa", "Bukele", "Arévalo", "Castro", "López Obrador",
           "Ortega", "Cortizo", "Peña", "Boluarte", "Abinader", "Lacalle Pou", "Maduro"]
agesP=[53,60,78,37,63,62,63,36,42,65,64,70,78,70,45,61,56,50,61]
countriesP=["Argentina", "Bolivia", "Brasil", "Chile", "Colombia", "Costa Rica", "Cuba",
            "Ecuador", "El Salvador", "Guatemala", "Honduras", "México", "Nicaragua", "Panamá",
            "Paraguay", "Perú", "República Dominicana", "Uruguay", "Venezuela"]
pol_orientationP=["Derecha", "Izquierda", "Izquierda", "Centroizquierda", "Izquierda", "Centroderecha",
                  "Izquierda", "Centroderecha", "Centro", "Izquierda", "Centroizquierda", "Izquierda",
                  "Izquierda", "Centro", "Centroderecha", "Centro", "Centroizquierda", "Centroderecha",
                  "Izquierda"]

DF1=dict(Surnames=SurnamesP,Ages=agesP,Countries=countriesP,Pol_orientation=pol_orientationP)

import pandas as pd

DFP=pd.DataFrame(DF1)
DFP
# Out:
#          Surnames  Ages             Countries  Pol_orientation
# 0           Milei    53             Argentina          Derecha
# 1            Arce    60               Bolivia        Izquierda
# 2        da Silva    78                Brasil        Izquierda
# 3           Boric    37                 Chile  Centroizquierda
# 4           Petro    63              Colombia        Izquierda
# 5          Chaves    62            Costa Rica    Centroderecha
# 6      Díaz-Canel    63                  Cuba        Izquierda
# 7           Noboa    36               Ecuador    Centroderecha
# 8          Bukele    42           El Salvador           Centro
# 9         Arévalo    65             Guatemala        Izquierda
# 10         Castro    64              Honduras  Centroizquierda
# 11  López Obrador    70                México        Izquierda
# 12         Ortega    78             Nicaragua        Izquierda
# 13        Cortizo    70                Panamá           Centro
# ...

# %%
# %%R
# SurnamesR=c("Milei", "Arce", "da Silva", "Boric", "Petro", "Chaves", "Díaz-Canel",
#            "Noboa", "Bukele", "Arévalo", "Castro", "López Obrador",
#            "Ortega", "Cortizo", "Peña", "Boluarte", "Abinader", "Lacalle Pou", "Maduro")
# agesR=c(53,60,78,37,63,62,63,36,42,65,64,70,78,70,45,61,56,50,61)
# countriesR=c("Argentina", "Bolivia", "Brasil", "Chile", "Colombia", "Costa Rica", "Cuba",
#             "Ecuador", "El Salvador", "Guatemala", "Honduras", "México", "Nicaragua", "Panamá",
#             "Paraguay", "Perú", "República Dominicana", "Uruguay", "Venezuela")
# pol_orientationR=c("Derecha", "Izquierda", "Izquierda", "Centroizquierda", "Izquierda", "Centroderecha",
#                   "Izquierda", "Centroderecha", "Centro", "Izquierda", "Centroizquierda", "Izquierda",
#                   "Izquierda", "Centro", "Centroderecha", "Centro", "Centroizquierda", "Centroderecha",
#                   "Izquierda")
#
# DF1R=list(Surname=SurnamesR,age=agesR,Country=countriesR,Pol_orientation=pol_orientationR)
#
# DFR=as.data.frame(do.call(cbind,DF1R))
# DFR
# Out:
#          Surname age              Country Pol_orientation
# 1          Milei  53            Argentina         Derecha
# 2           Arce  60              Bolivia       Izquierda
# 3       da Silva  78               Brasil       Izquierda
# 4          Boric  37                Chile Centroizquierda
# 5          Petro  63             Colombia       Izquierda
# 6         Chaves  62           Costa Rica   Centroderecha
# 7     Díaz-Canel  63                 Cuba       Izquierda
# 8          Noboa  36              Ecuador   Centroderecha
# 9         Bukele  42          El Salvador          Centro
# 10       Arévalo  65            Guatemala       Izquierda
# 11        Castro  64             Honduras Centroizquierda
# 12 López Obrador  70               México       Izquierda
# 13        Ortega  78            Nicaragua       Izquierda
# 14       Cortizo  70               Panamá          Centro
# 15          Peña  45             Paraguay   Centroderecha
# ...

# %% [markdown]
# Acceso

# %%
DFP.iloc[:,0]
# Out:
# 0             Milei
# 1              Arce
# 2          da Silva
# 3             Boric
# 4             Petro
# 5            Chaves
# 6        Díaz-Canel
# 7             Noboa
# 8            Bukele
# 9           Arévalo
# 10           Castro
# 11    López Obrador
# 12           Ortega
# 13          Cortizo
# 14             Peña
# 15         Boluarte
# 16         Abinader
# 17      Lacalle Pou
# 18           Maduro
# Name: Surnames, dtype: object

# %% [markdown]
# Se obtienen los apellidos.

# %%
# %%R
# DFR[,1]
# Out:
#  [1] "Milei"         "Arce"          "da Silva"      "Boric"
#  [5] "Petro"         "Chaves"        "Díaz-Canel"    "Noboa"
#  [9] "Bukele"        "Arévalo"       "Castro"        "López Obrador"
# [13] "Ortega"        "Cortizo"       "Peña"          "Boluarte"
# [17] "Abinader"      "Lacalle Pou"   "Maduro"

# %% [markdown]
# Se obtienen los apellidos.

# %%
DFP.iloc[:,[0,3]]
# Out:
#          Surnames  Pol_orientation
# 0           Milei          Derecha
# 1            Arce        Izquierda
# 2        da Silva        Izquierda
# 3           Boric  Centroizquierda
# 4           Petro        Izquierda
# 5          Chaves    Centroderecha
# 6      Díaz-Canel        Izquierda
# 7           Noboa    Centroderecha
# 8          Bukele           Centro
# 9         Arévalo        Izquierda
# 10         Castro  Centroizquierda
# 11  López Obrador        Izquierda
# 12         Ortega        Izquierda
# 13        Cortizo           Centro
# 14           Peña    Centroderecha
# 15       Boluarte           Centro
# 16       Abinader  Centroizquierda
# 17    Lacalle Pou    Centroderecha
# 18         Maduro        Izquierda
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %% [markdown]
# Se extraen los apellidos y las orientaciones políticas respectivas.

# %%
# %%R
# DFR[,c(1,3)]
# Out:
#          Surname              Country
# 1          Milei            Argentina
# 2           Arce              Bolivia
# 3       da Silva               Brasil
# 4          Boric                Chile
# 5          Petro             Colombia
# 6         Chaves           Costa Rica
# 7     Díaz-Canel                 Cuba
# 8          Noboa              Ecuador
# 9         Bukele          El Salvador
# 10       Arévalo            Guatemala
# 11        Castro             Honduras
# 12 López Obrador               México
# 13        Ortega            Nicaragua
# 14       Cortizo               Panamá
# 15          Peña             Paraguay
# 16      Boluarte                 Perú
# 17      Abinader República Dominicana
# 18   Lacalle Pou              Uruguay
# 19        Maduro            Venezuela

# %% [markdown]
# Se extraen los apellidos y sus países respectivos.

# %%
DFP.loc[:,'Surnames']
# Out:
# 0             Milei
# 1              Arce
# 2          da Silva
# 3             Boric
# 4             Petro
# 5            Chaves
# 6        Díaz-Canel
# 7             Noboa
# 8            Bukele
# 9           Arévalo
# 10           Castro
# 11    López Obrador
# 12           Ortega
# 13          Cortizo
# 14             Peña
# 15         Boluarte
# 16         Abinader
# 17      Lacalle Pou
# 18           Maduro
# Name: Surnames, dtype: object

# %% [markdown]
# Se obtienen los apellidos.

# %%
# %%R
# DFR[,'Surname']
# Out:
#  [1] "Milei"         "Arce"          "da Silva"      "Boric"
#  [5] "Petro"         "Chaves"        "Díaz-Canel"    "Noboa"
#  [9] "Bukele"        "Arévalo"       "Castro"        "López Obrador"
# [13] "Ortega"        "Cortizo"       "Peña"          "Boluarte"
# [17] "Abinader"      "Lacalle Pou"   "Maduro"

# %% [markdown]
# Se obtienen los apellidos.

# %%
DFP.loc[:,['Pol_orientation','Ages']]
# Out:
#     Pol_orientation  Ages
# 0           Derecha    53
# 1         Izquierda    60
# 2         Izquierda    78
# 3   Centroizquierda    37
# 4         Izquierda    63
# 5     Centroderecha    62
# 6         Izquierda    63
# 7     Centroderecha    36
# 8            Centro    42
# 9         Izquierda    65
# 10  Centroizquierda    64
# 11        Izquierda    70
# 12        Izquierda    78
# 13           Centro    70
# 14    Centroderecha    45
# 15           Centro    61
# 16  Centroizquierda    56
# 17    Centroderecha    50
# 18        Izquierda    61
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_18['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['Ages'].plot(kind='hist', bins=20, title='Ages')
# ...

# %% [markdown]
# Se extraen las orientaciones políticas y sus respectivas edades de los gobernantes.

# %%
# %%R
# DFR[,c('Country','Pol_orientation')]
# Out:
#                 Country Pol_orientation
# 1             Argentina         Derecha
# 2               Bolivia       Izquierda
# 3                Brasil       Izquierda
# 4                 Chile Centroizquierda
# 5              Colombia       Izquierda
# 6            Costa Rica   Centroderecha
# 7                  Cuba       Izquierda
# 8               Ecuador   Centroderecha
# 9           El Salvador          Centro
# 10            Guatemala       Izquierda
# 11             Honduras Centroizquierda
# 12               México       Izquierda
# 13            Nicaragua       Izquierda
# 14               Panamá          Centro
# 15             Paraguay   Centroderecha
# 16                 Perú          Centro
# 17 República Dominicana Centroizquierda
# 18              Uruguay   Centroderecha
# 19            Venezuela       Izquierda

# %% [markdown]
# Se obtienen los países y las orientaciones políticas.

# %%
DFP.Surnames
# Out:
# 0             Milei
# 1              Arce
# 2          da Silva
# 3             Boric
# 4             Petro
# 5            Chaves
# 6        Díaz-Canel
# 7             Noboa
# 8            Bukele
# 9           Arévalo
# 10           Castro
# 11    López Obrador
# 12           Ortega
# 13          Cortizo
# 14             Peña
# 15         Boluarte
# 16         Abinader
# 17      Lacalle Pou
# 18           Maduro
# Name: Surnames, dtype: object

# %% [markdown]
# Se obtienen los apellidos de los gobernantes en una columna.

# %%
# %%R
# DFR$Surname
# Out:
#  [1] "Milei"         "Arce"          "da Silva"      "Boric"
#  [5] "Petro"         "Chaves"        "Díaz-Canel"    "Noboa"
#  [9] "Bukele"        "Arévalo"       "Castro"        "López Obrador"
# [13] "Ortega"        "Cortizo"       "Peña"          "Boluarte"
# [17] "Abinader"      "Lacalle Pou"   "Maduro"

# %% [markdown]
# Se obtienen los apellidos de los gobernantes en una columna.

# %%
DFP.loc[4,'Countries']
# Out:
# 'Colombia'

# %% [markdown]
# Se obtiene el quinto elemento de Countries, Colombia.

# %%
DFP.iloc[7,3]
# Out:
# 'Centroderecha'

# %% [markdown]
# Se extrae el octavo elemento de las orientaciones políticas, Centroderecha.

# %%
# %%R
# DFR[3,'age']
# Out:
# [1] "78"

# %% [markdown]
# Se obtiene la tercera edad, que es 78.

# %%
DFP.loc[[3,16],['Surnames','Countries']]
# Out:
#     Surnames             Countries
# 3      Boric                 Chile
# 16  Abinader  República Dominicana
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_28['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_29.groupby('Surnames').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_30.groupby('Countries').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %% [markdown]
# Se extraen los valores 3 (Boric - Chile) y 16 (Abinader - República Dominicana).

# %%
# %%R
# DFR[c(8,17),c('age','Pol_orientation')]
# Out:
#    age Pol_orientation
# 8   36   Centroderecha
# 17  56 Centroizquierda

# %% [markdown]
# Se extraen los valores 8 (36 - Centroderecha) y 17 (56 - Centroizquierda).
